# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pltGender
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(df["Fare"].groupby(df["Sex"]).mean())
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
sns.histplot(data=df, x = "Pclass", hue = "Survived",legend = True, multiple="stack", stat= 'count')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Count'>

# %%
sns.lineplot(x=df["Sex"], y = df["Survived"])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
sns.histplot(data=df, x= "Fare", hue = "Survived", binwidth=10)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Count'>

# %%
sns.boxplot(data = df, x="Fare")
# Out:
# <AxesSubplot:xlabel='Fare'>

# %%
sns.violinplot(data = df, x = "Pclass", y = "Fare",hue = "Sex")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
sns.swarmplot(data = df, x = "Fare", y = "Sex", hue = "Survived")
# Out:
# /home/pict/.local/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 71.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/pict/.local/lib/python3.6/site-packages/seaborn/categorical.py:1296: UserWarning: 48.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Fare', ylabel='Sex'>

# %% [markdown]
# ### Part 2 of Assignment
# Write a code to check how the price of the ticket (column name: 'fare') for each passenger is distributed by plotting a histogram.

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.histplot(data = df,  x = "Fare")
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Count'>

# %%
sns.histplot(data = df, x = "PassengerId", y = "Fare")
# Out:
# <AxesSubplot:xlabel='PassengerId', ylabel='Fare'>

# %% [markdown]
# ### Observations:
# 1) There were more men is lower fare section than women.
# 2) Women and Children had a better chance for survival than men.
# 3) Mean fare was
